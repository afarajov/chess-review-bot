# %%
# Import the necessary libraries for chess analysis
import chess
import chess.pgn
import chess.engine
from chess.engine import Cp
import chess.polyglot
import math
import json
import csv
import time


# board.turn returns True if it's white's turn, False if it's black's turn.
turns = {
    True: "white",
    False: "black"
}

# ---- Пороги (в единицах win-rate, 0..100) ----
MISS_LOSS_THRESHOLD    = 12   # насколько ход хуже лучшего, чтобы считаться упущением
WINNING_OPPORTUNITY    = 55   # был доступен реальный перевес
SAVING_OPPORTUNITY     = 40   # был доступен реальный шанс сравнять/спастись
NOT_COLLAPSED_FLOOR    = 45   # после хода не рухнул слишком глубоко в минус

# Open a downloaded .bin file with all openings in polyglot format
books_url = "../material/rodent.bin"
books = chess.polyglot.open_reader(books_url)

# Open a downloaded .tsv file with the names of all openings
def load_opening_book(path):
    opening_book = {}
    with open(path, newline='', encoding='utf-8') as f:
        reader = csv.DictReader(f, delimiter='\t')
        for row in reader:
            opening_book[row['epd']] = (row['eco'], row['name'])
    return opening_book

openings_url = "../material/all.tsv"
openings = load_opening_book(openings_url)

# Open the PGN file for analysis and run the Stockfish.
pgn = open("../material/konteyni_vs_Snowstormme_2026.06.19.pgn")
engine = chess.engine.SimpleEngine.popen_uci(r"/opt/homebrew/Cellar/stockfish/18/bin/stockfish")

# The analyse_game function takes a PGN file and analyzes the game, returning a report with move evaluations.
def analyse_game(pgn):

    # Report template to store game analysis results
    report = {
        "game_id": 'abc123',
        "opening": '',
        "moves": [],
        "eval_history": [],
    }

    openings_state = {"openings_ended": False}

    opportunity = {
        "available_chance": False,
        "chance_for": None,
    }

    game = chess.pgn.read_game(pgn)
    board = game.board()

    info = engine.analyse(board, chess.engine.Limit(depth=16))
    prev_eval = info["score"].white().score(mate_score=10000)

    for move in game.mainline_moves():
        t_move = time.time()

        mover = turns[board.turn]
        move_number = board.fullmove_number

        best_moves = info["pv"]

        board.push(move)
        to_move = turns[board.turn]

        move_info = {
            "move_number": move_number,
            "move": move.uci(),
            "mover": mover,
            "to_move": to_move,
            "mate_in": None,
            "evaluation": None,
            "category": None,
            "fen": board.fen(),
        }
        
        print(board)
        print("\n")

        info = engine.analyse(board, chess.engine.Limit(depth=16))
        eval = info["score"].white().score(mate_score=10000)
        move_info["evaluation"] = eval
        
        category = categorize_move(eval, prev_eval, mover, move, best_moves, board, openings_state, report, opportunity)
        move_info["category"] = category


        print(f"{mover} made a move: {move.uci()}. Evaluation: {prev_eval} -> {eval}: {category}. {to_move} to move.")
        print(f"move took {time.time() - t_move:.2f}s")
        print("\n")
        print("\n")

        prev_eval = eval

        if info["score"].is_mate():
            move_info["mate_in"] = info['score'].white().mate()

        report["moves"].append(move_info)
        report["eval_history"].append(eval)

    return report

def categorize_move(eval, prev_eval, mover, move, best_moves, board, openings_state, report, opportunity):
    current_winrate = calculate_winrate(eval)
    prev_winrate = calculate_winrate(prev_eval)

    if is_book_move(board, report) and not openings_state['openings_ended']:
        return "Book"
    else:
        openings_state['openings_ended'] = True

    if is_forced_move(report):
        return "Forced"

    mover_curr_wr = current_winrate if mover == "white" else 100 - current_winrate

    board_before = board.copy()
    board_before.pop()

    if best_moves and is_miss(prev_eval, move, best_moves[0], mover, mover_curr_wr, opportunity):
        opportunity['available_chance'] = False
        opportunity['chance_for'] = None
        return "Miss"

    return classic_moves(move, mover, best_moves, current_winrate, prev_winrate, opportunity)

def is_book_move(board, report):
    last_move = board.pop()

    continuations = []
    for continuation in books.find_all(board):
        continuations.append(continuation.move)
    board.push(last_move)

    opening = openings.get(board.epd())
    if opening != None:
        report['opening'] = opening[1]

    book = last_move in continuations
    return book

def is_forced_move(report):
    if len(report['moves']) == 0:
        return False
    board = chess.Board(report['moves'][-1]["fen"])
    forced = board.legal_moves.count() == 1
    return forced


def winrate_pov(cp_white, mover):
    wr_white = calculate_winrate(cp_white)
    return wr_white if mover == "white" else 100 - wr_white

def is_miss(prev_eval, played_move, best_move, mover, current_winrate, opportunity):
    if not opportunity['available_chance'] or mover != opportunity['chance_for'] or played_move == best_move:
        return False

    wr_best = winrate_pov(prev_eval, mover)
    wr_played = current_winrate
    loss = wr_best - wr_played

    opportunity_existed = wr_best >= WINNING_OPPORTUNITY or wr_best >= SAVING_OPPORTUNITY
    gave_up_enough = loss >= MISS_LOSS_THRESHOLD
    not_collapsed = wr_played >= NOT_COLLAPSED_FLOOR

    return opportunity_existed and gave_up_enough and not_collapsed

# The classic_moves function categorizes the move based on its quality compared to the best move and the change in winrate. 
# Which does not include special moves such as forced, book, , miss, great, brilliant moves.
def classic_moves(move, mover, best_moves, current_winrate, prev_winrate, opportunity):

    if mover == "white":
        winrate_change = prev_winrate - current_winrate
    else:
        winrate_change = current_winrate - prev_winrate
    
    if move == best_moves[0]:
        return "Best"
    elif winrate_change <= 2:
        return "Excellent"
    elif winrate_change <= 5:   
        return "Good"
    elif winrate_change <= 10:
        return "Inaccuracy"
    elif winrate_change <= 20:
        opportunity["available_chance"] = True
        opportunity["chance_for"] = "black" if mover == "white" else "white"
        return "Mistake"
    else:
        opportunity["available_chance"] = True
        opportunity["chance_for"] = "black" if mover == "white" else "white"
        return "Blunder"


def calculate_winrate(x):
    y = 50 + 50 * ( 2 / (1 + math.e**(-0.004 * x)) -1)
    return y

print(json.dumps(analyse_game(pgn), indent=2))

engine.quit()
# Out:
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . P . . .
# . . . . . . . .
# P P P P . P P P
# R N B Q K B N R
#
#
# white made a move: e2e4. Evaluation: 47 -> 37: Book. black to move.
# move took 0.24s
#
#
#
#
# r n b q k b n r
# p p p p . p p p
# . . . . p . . .
# . . . . . . . .
# . . . . P . . .
# . . . . . . . .
# P P P P . P P P
# R N B Q K B N R
#
#
# black made a move: e7e6. Evaluation: 37 -> 47: Book. white to move.
# move took 0.14s
#
#
#
#
# r n b q k b n r
# p p p p . p p p
# . . . . p . . .
# . . . . . . . .
# . . . . P . . .
# . . . . . N . .
# P P P P . P P P
# R N B Q K B . R
#
#
# white made a move: g1f3. Evaluation: 47 -> 35: Book. black to move.
# move took 0.16s
#
#
#
#
# r n b q k b n r
# p p p . . p p p
# . . . . p . . .
# . . . p . . . .
# . . . . P . . .
# . . . . . N . .
# P P P P . P P P
# R N B Q K B . R
#
#
# black made a move: d7d5. Evaluation: 35 -> 33: Book. white to move.
# move took 0.16s
#
#
#
#
# r n b q k b n r
# p p p . . p p p
# . . . . p . . .
# . . . P . . . .
# . . . . . . . .
# . . . . . N . .
# P P P P . P P P
# R N B Q K B . R
#
#
# white made a move: e4d5. Evaluation: 33 -> 25: Book. black to move.
# move took 0.18s
#
#
#
#
# r n b q k b n r
# p p p . . p p p
# . . . . . . . .
# . . . p . . . .
# . . . . . . . .
# . . . . . N . .
# P P P P . P P P
# R N B Q K B . R
#
#
# black made a move: e6d5. Evaluation: 25 -> 33: Book. white to move.
# move took 0.12s
#
#
#
#
# r n b q k b n r
# p p p . . p p p
# . . . . . . . .
# . . . p N . . .
# . . . . . . . .
# . . . . . . . .
# P P P P . P P P
# R N B Q K B . R
#
#
# white made a move: f3e5. Evaluation: 33 -> -50: Inaccuracy. black to move.
# move took 0.31s
#
#
#
#
# r n b . k b n r
# p p p . q p p p
# . . . . . . . .
# . . . p N . . .
# . . . . . . . .
# . . . . . . . .
# P P P P . P P P
# R N B Q K B . R
#
#
# black made a move: d8e7. Evaluation: -50 -> -43: Excellent. white to move.
# move took 0.43s
#
#
#
#
# r n b . k b n r
# p p p . q p p p
# . . . . . . . .
# . . . p N . . .
# . . . . . . . .
# . . . . . . . .
# P P P P Q P P P
# R N B . K B . R
#
#
# white made a move: d1e2. Evaluation: -43 -> -40: Best. black to move.
# move took 0.36s
#
#
#
#
# r n b . k b n r
# p p p . q . p p
# . . . . . p . .
# . . . p N . . .
# . . . . . . . .
# . . . . . . . .
# P P P P Q P P P
# R N B . K B . R
#
#
# black made a move: f7f6. Evaluation: -40 -> -43: Excellent. white to move.
# move took 0.22s
#
#
#
#
# r n b . k b n r
# p p p . q . p p
# . . . . . p . .
# . . . p . . . .
# . . N . . . . .
# . . . . . . . .
# P P P P Q P P P
# R N B . K B . R
#
#
# white made a move: e5c4. Evaluation: -43 -> -437: Blunder. black to move.
# move took 0.04s
#
#
#
#
# r n b . k b n r
# p p p . . . p p
# . . . . . p . .
# . . . p . . . .
# . . N . . . . .
# . . . . . . . .
# P P P P q P P P
# R N B . K B . R
#
#
# black made a move: e7e2. Evaluation: -437 -> -424: Excellent. white to move.
# move took 0.28s
#
#
#
#
# r n b . k b n r
# p p p . . . p p
# . . . . . p . .
# . . . p . . . .
# . . N . . . . .
# . . . . . . . .
# P P P P B P P P
# R N B . K . . R
#
#
# white made a move: f1e2. Evaluation: -424 -> -412: Best. black to move.
# move took 0.14s
#
#
#
#
# r n . . k b n r
# p p p . . . p p
# . . . . b p . .
# . . . p . . . .
# . . N . . . . .
# . . . . . . . .
# P P P P B P P P
# R N B . K . . R
#
#
# black made a move: c8e6. Evaluation: -412 -> -27: Miss. white to move.
# move took 0.19s
#
#
#
#
# r n . . k b n r
# p p p . . . p p
# . . . . b p . .
# N . . p . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P B P P P
# R N B . K . . R
#
#
# white made a move: c4a5. Evaluation: -27 -> -28: Best. black to move.
# move took 0.06s
#
#
#
#
# r n . . k . n r
# p p p . . . p p
# . . . b b p . .
# N . . p . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P B P P P
# R N B . K . . R
#
#
# black made a move: f8d6. Evaluation: -28 -> 158: Mistake. white to move.
# move took 0.14s
#
#
#
#
# r n . . k . n r
# p p p . . . p p
# . . . b b p . .
# N . . p . . . .
# . . . P . . . .
# . . . . . . . .
# P P P . B P P P
# R N B . K . . R
#
#
# white made a move: d2d4. Evaluation: 158 -> -49: Miss. black to move.
# move took 0.09s
#
#
#
#
# r . . . k . n r
# p p p . . . p p
# . . n b b p . .
# N . . p . . . .
# . . . P . . . .
# . . . . . . . .
# P P P . B P P P
# R N B . K . . R
#
#
# black made a move: b8c6. Evaluation: -49 -> 82: Mistake. white to move.
# move took 0.12s
#
#
#
#
# r . . . k . n r
# p p p . . . p p
# . . N b b p . .
# . . . p . . . .
# . . . P . . . .
# . . . . . . . .
# P P P . B P P P
# R N B . K . . R
#
#
# white made a move: a5c6. Evaluation: 82 -> 7: Inaccuracy. black to move.
# move took 0.30s
#
#
#
#
# r . . . k . n r
# p . p . . . p p
# . . p b b p . .
# . . . p . . . .
# . . . P . . . .
# . . . . . . . .
# P P P . B P P P
# R N B . K . . R
#
#
# black made a move: b7c6. Evaluation: 7 -> 10: Best. white to move.
# move took 0.30s
#
#
#
#
# r . . . k . n r
# p . p . . . p p
# . . p b b p . .
# . . . p . . . .
# . . . P . . . .
# . . N . . . . .
# P P P . B P P P
# R . B . K . . R
#
#
# white made a move: b1c3. Evaluation: 10 -> -34: Good. black to move.
# move took 0.19s
#
#
#
#
# r . . . k . . r
# p . p . n . p p
# . . p b b p . .
# . . . p . . . .
# . . . P . . . .
# . . N . . . . .
# P P P . B P P P
# R . B . K . . R
#
#
# black made a move: g8e7. Evaluation: -34 -> -18: Excellent. white to move.
# move took 0.13s
#
#
#
#
# r . . . k . . r
# p . p . n . p p
# . . p b b p . .
# . . . p . . . .
# P . . P . . . .
# . . N . . . . .
# . P P . B P P P
# R . B . K . . R
#
#
# white made a move: a2a4. Evaluation: -18 -> -92: Inaccuracy. black to move.
# move took 0.19s
#
#
#
#
# r . . . k . . r
# p . p . n . p p
# . . . b b p . .
# . . p p . . . .
# P . . P . . . .
# . . N . . . . .
# . P P . B P P P
# R . B . K . . R
#
#
# black made a move: c6c5. Evaluation: -92 -> 24: Mistake. white to move.
# move took 0.36s
#
#
#
#
# r . . . k . . r
# p . p . n . p p
# . . . b b p . .
# . . P p . . . .
# P . . . . . . .
# . . N . . . . .
# . P P . B P P P
# R . B . K . . R
#
#
# white made a move: d4c5. Evaluation: 24 -> 8: Excellent. black to move.
# move took 0.40s
#
#
#
#
# r . . . k . . r
# p . p . n . p p
# . . . . b p . .
# . . b p . . . .
# P . . . . . . .
# . . N . . . . .
# . P P . B P P P
# R . B . K . . R
#
#
# black made a move: d6c5. Evaluation: 8 -> 16: Best. white to move.
# move took 0.22s
#
#
#
#
# r . . . k . . r
# p . p . n . p p
# . . . . b p . .
# . N b p . . . .
# P . . . . . . .
# . . . . . . . .
# . P P . B P P P
# R . B . K . . R
#
#
# white made a move: c3b5. Evaluation: 16 -> -5: Good. black to move.
# move took 0.23s
#
#
#
#
# . . r . k . . r
# p . p . n . p p
# . . . . b p . .
# . N b p . . . .
# P . . . . . . .
# . . . . . . . .
# . P P . B P P P
# R . B . K . . R
#
#
# black made a move: a8c8. Evaluation: -5 -> 50: Inaccuracy. white to move.
# move took 0.22s
#
#
#
#
# . . r . k . . r
# p . p . n . p p
# . . . . b p . .
# . N b p . . . .
# P . . . . . . .
# . . . . . P . .
# . P P . B . P P
# R . B . K . . R
#
#
# white made a move: f2f3. Evaluation: 50 -> -99: Mistake. black to move.
# move took 0.36s
#
#
#
#
# . . r . k . . r
# p . . . n . p p
# . . p . b p . .
# . N b p . . . .
# P . . . . . . .
# . . . . . P . .
# . P P . B . P P
# R . B . K . . R
#
#
# black made a move: c7c6. Evaluation: -99 -> -102: Best. white to move.
# move took 0.15s
#
#
#
#
# . . r . k . . r
# N . . . n . p p
# . . p . b p . .
# . . b p . . . .
# P . . . . . . .
# . . . . . P . .
# . P P . B . P P
# R . B . K . . R
#
#
# white made a move: b5a7. Evaluation: -102 -> -360: Blunder. black to move.
# move took 0.13s
#
#
#
#
# . . . . k . . r
# N . r . n . p p
# . . p . b p . .
# . . b p . . . .
# P . . . . . . .
# . . . . . P . .
# . P P . B . P P
# R . B . K . . R
#
#
# black made a move: c8c7. Evaluation: -360 -> -273: Inaccuracy. white to move.
# move took 0.10s
#
#
#
#
# . . . . k . . r
# . . r . n . p p
# . . N . b p . .
# . . b p . . . .
# P . . . . . . .
# . . . . . P . .
# . P P . B . P P
# R . B . K . . R
#
#
# white made a move: a7c6. Evaluation: -273 -> -256: Best. black to move.
# move took 0.34s
#
#
#
#
# . . . . k . . r
# . . . . n . p p
# . . r . b p . .
# . . b p . . . .
# P . . . . . . .
# . . . . . P . .
# . P P . B . P P
# R . B . K . . R
#
#
# black made a move: c7c6. Evaluation: -256 -> -170: Inaccuracy. white to move.
# move took 0.12s
#
#
#
#
# . . . . k . . r
# . . . . n . p p
# . . r . b p . .
# . B b p . . . .
# P . . . . . . .
# . . . . . P . .
# . P P . . . P P
# R . B . K . . R
#
#
# white made a move: e2b5. Evaluation: -170 -> -163: Best. black to move.
# move took 0.09s
#
#
#
#
# . . . . k . . r
# . . . b n . p p
# . . r . . p . .
# . B b p . . . .
# P . . . . . . .
# . . . . . P . .
# . P P . . . P P
# R . B . K . . R
#
#
# black made a move: e6d7. Evaluation: -163 -> -92: Inaccuracy. white to move.
# move took 0.17s
#
#
#
#
# . . . . k . . r
# . . . b n . p p
# . . B . . p . .
# . . b p . . . .
# P . . . . . . .
# . . . . . P . .
# . P P . . . P P
# R . B . K . . R
#
#
# white made a move: b5c6. Evaluation: -92 -> -76: Best. black to move.
# move took 0.18s
#
#
#
#
# . . . . k . . r
# . . . . n . p p
# . . b . . p . .
# . . b p . . . .
# P . . . . . . .
# . . . . . P . .
# . P P . . . P P
# R . B . K . . R
#
#
# black made a move: d7c6. Evaluation: -76 -> -10: Inaccuracy. white to move.
# move took 0.21s
#
#
#
#
# . . . . k . . r
# . . . . n . p p
# . . b . . p . .
# P . b p . . . .
# . . . . . . . .
# . . . . . P . .
# . P P . . . P P
# R . B . K . . R
#
#
# white made a move: a4a5. Evaluation: -10 -> -126: Mistake. black to move.
# move took 0.13s
#
#
#
#
# . . . . k . . r
# . . . . n . p p
# . . b . . p . .
# P . . p . . . .
# . b . . . . . .
# . . . . . P . .
# . P P . . . P P
# R . B . K . . R
#
#
# black made a move: c5b4. Evaluation: -126 -> -12: Mistake. white to move.
# move took 0.26s
#
#
#
#
# . . . . k . . r
# . . . . n . p p
# . . b . . p . .
# P . . p . . . .
# . b . . . . . .
# . . P . . P . .
# . P . . . . P P
# R . B . K . . R
#
#
# white made a move: c2c3. Evaluation: -12 -> 0: Best. black to move.
# move took 0.20s
#
#
#
#
# . . . . k . . r
# . . . . n . p p
# . . b . . p . .
# b . . p . . . .
# . . . . . . . .
# . . P . . P . .
# . P . . . . P P
# R . B . K . . R
#
#
# black made a move: b4a5. Evaluation: 0 -> 443: Blunder. white to move.
# move took 0.13s
#
#
#
#
# . . . . k . . r
# . . . . n . p p
# . . b . . p . .
# R . . p . . . .
# . . . . . . . .
# . . P . . P . .
# . P . . . . P P
# . . B . K . . R
#
#
# white made a move: a1a5. Evaluation: 443 -> 446: Best. black to move.
# move took 0.06s
#
#
#
#
# . . . . . r k .
# . . . . n . p p
# . . b . . p . .
# R . . p . . . .
# . . . . . . . .
# . . P . . P . .
# . P . . . . P P
# . . B . K . . R
#
#
# black made a move: e8g8. Evaluation: 446 -> 452: Excellent. white to move.
# move took 0.04s
#
#
#
#
# . . . . . r k .
# R . . . n . p p
# . . b . . p . .
# . . . p . . . .
# . . . . . . . .
# . . P . . P . .
# . P . . . . P P
# . . B . K . . R
#
#
# white made a move: a5a7. Evaluation: 452 -> 411: Good. black to move.
# move took 0.19s
#
#
#
#
# . . . . r . k .
# R . . . n . p p
# . . b . . p . .
# . . . p . . . .
# . . . . . . . .
# . . P . . P . .
# . P . . . . P P
# . . B . K . . R
#
#
# black made a move: f8e8. Evaluation: 411 -> 429: Excellent. white to move.
# move took 0.19s
#
#
#
#
# . . . . r . k .
# R . . . n . p p
# . . b . . p . .
# . . . p . . . .
# . . . . . B . .
# . . P . . P . .
# . P . . . . P P
# . . . . K . . R
#
#
# white made a move: c1f4. Evaluation: 429 -> -325: Blunder. black to move.
# move took 0.05s
#
#
#
#
# . . . . r . k .
# R . . . . . p p
# . . b . . p n .
# . . . p . . . .
# . . . . . B . .
# . . P . . P . .
# . P . . . . P P
# . . . . K . . R
#
#
# black made a move: e7g6. Evaluation: -325 -> 30: Miss. white to move.
# move took 0.05s
#
#
#
#
# . . . . r . k .
# R . . . . . p p
# . . b . . p n .
# . . . p . . . .
# . . . . . B . .
# . . P . . P . .
# . P . . . K P P
# . . . . . . . R
#
#
# white made a move: e1f2. Evaluation: 30 -> -4: Good. black to move.
# move took 0.45s
#
#
#
#
# . . . . r . k .
# R . . . . . p p
# . . b . . p . .
# . . . p . . . .
# . . . . . n . .
# . . P . . P . .
# . P . . . K P P
# . . . . . . . R
#
#
# black made a move: g6f4. Evaluation: -4 -> -3: Best. white to move.
# move took 0.04s
#
#
#
#
# . . . . r . k .
# R . . . . . p p
# . . b . . p . .
# . . . p . . . .
# . . . . . n . .
# . . P . . P K .
# . P . . . . P P
# . . . . . . . R
#
#
# white made a move: f2g3. Evaluation: -3 -> 0: Best. black to move.
# move took 0.14s
#
#
#
#
# . . . . r . k .
# R . . . . . p p
# . . b . n p . .
# . . . p . . . .
# . . . . . . . .
# . . P . . P K .
# . P . . . . P P
# . . . . . . . R
#
#
# black made a move: f4e6. Evaluation: 0 -> 16: Excellent. white to move.
# move took 0.20s
#
#
#
#
# . . . . r . k .
# R . . . . . p p
# . . b . n p . .
# . . . p . . . .
# . . . . . . . .
# . . P . . P K .
# . P . . . . P P
# . . . . R . . .
#
#
# white made a move: h1e1. Evaluation: 16 -> 18: Best. black to move.
# move took 0.10s
#
#
#
#
# . . . . r . k .
# R . . . . . p p
# . . b . . p . .
# . . n p . . . .
# . . . . . . . .
# . . P . . P K .
# . P . . . . P P
# . . . . R . . .
#
#
# black made a move: e6c5. Evaluation: 18 -> 52: Good. white to move.
# move took 0.22s
#
#
#
#
# . . . . R . k .
# R . . . . . p p
# . . b . . p . .
# . . n p . . . .
# . . . . . . . .
# . . P . . P K .
# . P . . . . P P
# . . . . . . . .
#
#
# white made a move: e1e8. Evaluation: 52 -> 53: Excellent. black to move.
# move took 0.24s
#
#
#
#
# . . . . b . k .
# R . . . . . p p
# . . . . . p . .
# . . n p . . . .
# . . . . . . . .
# . . P . . P K .
# . P . . . . P P
# . . . . . . . .
#
#
# black made a move: c6e8. Evaluation: 53 -> 43: Forced. white to move.
# move took 0.12s
#
#
#
#
# R . . . b . k .
# . . . . . . p p
# . . . . . p . .
# . . n p . . . .
# . . . . . . . .
# . . P . . P K .
# . P . . . . P P
# . . . . . . . .
#
#
# white made a move: a7a8. Evaluation: 43 -> 16: Good. black to move.
# move took 0.19s
#
#
#
#
# R . . . b k . .
# . . . . . . p p
# . . . . . p . .
# . . n p . . . .
# . . . . . . . .
# . . P . . P K .
# . P . . . . P P
# . . . . . . . .
#
#
# black made a move: g8f8. Evaluation: 16 -> 15: Best. white to move.
# move took 0.09s
#
#
#
#
# R . . . b k . .
# . . . . . . p p
# . . . . . p . .
# . . n p . . . .
# . P . . . . . .
# . . P . . P K .
# . . . . . . P P
# . . . . . . . .
#
#
# white made a move: b2b4. Evaluation: 15 -> 20: Best. black to move.
# move took 0.18s
#
#
#
#
# R . . . b k . .
# . . . . . . p p
# . . . . . p . .
# . . . p . . . .
# . P . . . . . .
# . n P . . P K .
# . . . . . . P P
# . . . . . . . .
#
#
# black made a move: c5b3. Evaluation: 20 -> 335: Blunder. white to move.
# move took 0.09s
#
#
#
#
# R . . . b k . .
# . . . . . . p p
# . . . . . p . .
# . P . p . . . .
# . . . . . . . .
# . n P . . P K .
# . . . . . . P P
# . . . . . . . .
#
#
# white made a move: b4b5. Evaluation: 335 -> 397: Best. black to move.
# move took 1.16s
#
#
#
#
# R . . . b k . .
# . . . . . . p p
# . . . . . p . .
# . P . p . . . .
# . . . . . . . .
# . . P . . P K .
# . . . n . . P P
# . . . . . . . .
#
#
# black made a move: b3d2. Evaluation: 397 -> 658: Mistake. white to move.
# move took 0.05s
#
#
#
#
# R . . . b k . .
# . . . . . . p p
# . P . . . p . .
# . . . p . . . .
# . . . . . . . .
# . . P . . P K .
# . . . n . . P P
# . . . . . . . .
#
#
# white made a move: b5b6. Evaluation: 658 -> 666: Best. black to move.
# move took 0.08s
#
#
#
#
# R . . . b k . .
# . . . . . . p p
# . P . . . p . .
# . . . . . . . .
# . . . p . . . .
# . . P . . P K .
# . . . n . . P P
# . . . . . . . .
#
#
# black made a move: d5d4. Evaluation: 666 -> 788: Good. white to move.
# move took 0.03s
#
#
#
#
# R . . . b k . .
# . P . . . . p p
# . . . . . p . .
# . . . . . . . .
# . . . p . . . .
# . . P . . P K .
# . . . n . . P P
# . . . . . . . .
#
#
# white made a move: b6b7. Evaluation: 788 -> 893: Best. black to move.
# move took 0.15s
#
#
#
#
# R . . . b k . .
# . P . . . . p p
# . . . . . p . .
# . . . . . . . .
# . . . . . . . .
# . . p . . P K .
# . . . n . . P P
# . . . . . . . .
#
#
# black made a move: d4c3. Evaluation: 893 -> 9990: Good. white to move.
# move took 0.01s
#
#
#
#
# R Q . . b k . .
# . . . . . . p p
# . . . . . p . .
# . . . . . . . .
# . . . . . . . .
# . . p . . P K .
# . . . n . . P P
# . . . . . . . .
#
#
# white made a move: b7b8q. Evaluation: 9990 -> 9991: Best. black to move.
# move took 0.00s
#
#
#
#
# R Q . . b . . .
# . . . . . k p p
# . . . . . p . .
# . . . . . . . .
# . . . . . . . .
# . . p . . P K .
# . . . n . . P P
# . . . . . . . .
#
#
# black made a move: f8f7. Evaluation: 9991 -> 9999: Excellent. white to move.
# move took 0.00s
#
#
#
#
# R . . . Q . . .
# . . . . . k p p
# . . . . . p . .
# . . . . . . . .
# . . . . . . . .
# . . p . . P K .
# . . . n . . P P
# . . . . . . . .
#
#
# white made a move: b8e8. Evaluation: 9999 -> 10000: Best. black to move.
# move took 0.00s
#
#
#
#
# {
#   "game_id": "abc123",
#   "opening": "French Defense: Knight Variation",
#   "moves": [
#     {
#       "move_number": 1,
#       "move": "e2e4",
#       "mover": "white",
#       "to_move": "black",
#       "mate_in": null,
#       "evaluation": 37,
#       "category": "Book",
#       "fen": "rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR b KQkq - 0 1"
#     },
#     {
#       "move_number": 1,
#       "move": "e7e6",
#       "mover": "black",
#       "to_move": "white",
#       "mate_in": null,
#       "evaluation": 47,
#       "category": "Book",
#       "fen": "rnbqkbnr/pppp1ppp/4p3/8/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2"
#     },
#     {
#       "move_number": 2,
#       "move": "g1f3",
#       "mover": "white",
#       "to_move": "black",
#       "mate_in": null,
#       "evaluation": 35,
#       "category": "Book",
#       "fen": "rnbqkbnr/pppp1ppp/4p3/8/4P3/5N2/PPPP1PPP/RNBQKB1R b KQkq - 1 2"
#     },
#     {
#       "move_number": 2,
#       "move": "d7d5",
#       "mover": "black",
#       "to_move": "white",
#       "mate_in": null,
#       "evaluation": 33,
#       "category": "Book",
#       "fen": "rnbqkbnr/ppp2ppp/4p3/3p4/4P3/5N2/PPPP1PPP/RNBQKB1R w KQkq - 0 3"
#     },
#     {
#       "move_number": 3,
#       "move": "e4d5",
#       "mover": "white",
#       "to_move": "black",
#       "mate_in": null,
#       "evaluation": 25,
#       "category": "Book",
#       "fen": "rnbqkbnr/ppp2ppp/4p3/3P4/8/5N2/PPPP1PPP/RNBQKB1R b KQkq - 0 3"
#     },
#     {
#       "move_number": 3,
#       "move": "e6d5",
#       "mover": "black",
#       "to_move": "white",
#       "mate_in": null,
#       "evaluation": 33,
#       "category": "Book",
#       "fen": "rnbqkbnr/ppp2ppp/8/3p4/8/5N2/PPPP1PPP/RNBQKB1R w KQkq - 0 4"
#     },
#     {
#       "move_number": 4,
#       "move": "f3e5",
#       "mover": "white",
#       "to_move": "black",
#       "mate_in": null,
#       "evaluation": -50,
#       "category": "Inaccuracy",
#       "fen": "rnbqkbnr/ppp2ppp/8/3pN3/8/8/PPPP1PPP/RNBQKB1R b KQkq - 1 4"
#     },
#     {
#       "move_number": 4,
#       "move": "d8e7",
#       "mover": "black",
#       "to_move": "white",
#       "mate_in": null,
#       "evaluation": -43,
#       "category": "Excellent",
#       "fen": "rnb1kbnr/ppp1qppp/8/3pN3/8/8/PPPP1PPP/RNBQKB1R w KQkq - 2 5"
#     },
#     {
#       "move_number": 5,
#       "move": "d1e2",
#       "mover": "white",
#       "to_move": "black",
#       "mate_in": null,
#       "evaluation": -40,
#       "category": "Best",
#       "fen": "rnb1kbnr/ppp1qppp/8/3pN3/8/8/PPPPQPPP/RNB1KB1R b KQkq - 3 5"
#     },
#     {
#       "move_number": 5,
#       "move": "f7f6",
#       "mover": "black",
#       "to_move": "white",
#       "mate_in": null,
#       "evaluation": -43,
#       "category": "Excellent",
#       "fen": "rnb1kbnr/ppp1q1pp/5p2/3pN3/8/8/PPPPQPPP/RNB1KB1R w KQkq - 0 6"
#     },
#     {
#       "move_number": 6,
#       "move": "e5c4",
#       "mover": "white",
#       "to_move": "black",
#       "mate_in": null,
#       "evaluation": -437,
#       "category": "Blunder",
#       "fen": "rnb1kbnr/ppp1q1pp/5p2/3p4/2N5/8/PPPPQPPP/RNB1KB1R b KQkq - 1 6"
#     },
#     {
#       "move_number": 6,
#       "move": "e7e2",
#       "mover": "black",
#       "to_move": "white",
#       "mate_in": null,
#       "evaluation": -424,
#       "category": "Excellent",
#       "fen": "rnb1kbnr/ppp3pp/5p2/3p4/2N5/8/PPPPqPPP/RNB1KB1R w KQkq - 0 7"
#     },
#     {
#       "move_number": 7,
#       "move": "f1e2",
#       "mover": "white",
#       "to_move": "black",
#       "mate_in": null,
#       "evaluation": -412,
#       "category": "Best",
#       "fen": "rnb1kbnr/ppp3pp/5p2/3p4/2N5/8/PPPPBPPP/RNB1K2R b KQkq - 0 7"
#     },
#     {
#       "move_number": 7,
#       "move": "c8e6",
#       "mover": "black",
#       "to_move": "white",
#       "mate_in": null,
#       "evaluation": -27,
#       "category": "Miss",
#       "fen": "rn2kbnr/ppp3pp/4bp2/3p4/2N5/8/PPPPBPPP/RNB1K2R w KQkq - 1 8"
#     },
#     {
#       "move_number": 8,
#       "move": "c4a5",
#       "mover": "white",
#       "to_move": "black",
#       "mate_in": null,
#       "evaluation": -28,
#       "category": "Best",
#       "fen": "rn2kbnr/ppp3pp/4bp2/N2p4/8/8/PPPPBPPP/RNB1K2R b KQkq - 2 8"
#     },
#     {
#       "move_number": 8,
#       "move": "f8d6",
#       "mover": "black",
#       "to_move": "white",
#       "mate_in": null,
#       "evaluation": 158,
#       "category": "Mistake",
#       "fen": "rn2k1nr/ppp3pp/3bbp2/N2p4/8/8/PPPPBPPP/RNB1K2R w KQkq - 3 9"
#     },
#     {
#       "move_number": 9,
#       "move": "d2d4",
#       "mover": "white",
#       "to_move": "black",
#       "mate_in": null,
#       "evaluation": -49,
#       "category": "Miss",
#       "fen": "rn2k1nr/ppp3pp/3bbp2/N2p4/3P4/8/PPP1BPPP/RNB1K2R b KQkq - 0 9"
#     },
#     {
#       "move_number": 9,
#       "move": "b8c6",
#       "mover": "black",
#       "to_move": "white",
#       "mate_in": null,
#       "evaluation": 82,
#       "category": "Mistake",
#       "fen": "r3k1nr/ppp3pp/2nbbp2/N2p4/3P4/8/PPP1BPPP/RNB1K2R w KQkq - 1 10"
#     },
#     {
#       "move_number": 10,
#       "move": "a5c6",
#       "mover": "white",
#       "to_move": "black",
#       "mate_in": null,
#       "evaluation": 7,
#       "category": "Inaccuracy",
#       "fen": "r3k1nr/ppp3pp/2Nbbp2/3p4/3P4/8/PPP1BPPP/RNB1K2R b KQkq - 0 10"
#     },
#     {
#       "move_number": 10,
#       "move": "b7c6",
#       "mover": "black",
#       "to_move": "white",
#       "mate_in": null,
#       "evaluation": 10,
#       "category": "Best",
#       "fen": "r3k1nr/p1p3pp/2pbbp2/3p4/3P4/8/PPP1BPPP/RNB1K2R w KQkq - 0 11"
#     },
#     {
#       "move_number": 11,
#       "move": "b1c3",
#       "mover": "white",
#       "to_move": "black",
#       "mate_in": null,
#       "evaluation": -34,
#       "category": "Good",
#       "fen": "r3k1nr/p1p3pp/2pbbp2/3p4/3P4/2N5/PPP1BPPP/R1B1K2R b KQkq - 1 11"
#     },
#     {
#       "move_number": 11,
#       "move": "g8e7",
#       "mover": "black",
#       "to_move": "white",
#       "mate_in": null,
#       "evaluation": -18,
#       "category": "Excellent",
#       "fen": "r3k2r/p1p1n1pp/2pbbp2/3p4/3P4/2N5/PPP1BPPP/R1B1K2R w KQkq - 2 12"
#     },
#     {
#       "move_number": 12,
#       "move": "a2a4",
#       "mover": "white",
#       "to_move": "black",
#       "mate_in": null,
#       "evaluation": -92,
#       "category": "Inaccuracy",
#       "fen": "r3k2r/p1p1n1pp/2pbbp2/3p4/P2P4/2N5/1PP1BPPP/R1B1K2R b KQkq - 0 12"
#     },
#     {
#       "move_number": 12,
#       "move": "c6c5",
#       "mover": "black",
#       "to_move": "white",
#       "mate_in": null,
#       "evaluation": 24,
#       "category": "Mistake",
#       "fen": "r3k2r/p1p1n1pp/3bbp2/2pp4/P2P4/2N5/1PP1BPPP/R1B1K2R w KQkq - 0 13"
#     },
#     {
#       "move_number": 13,
#       "move": "d4c5",
#       "mover": "white",
#       "to_move": "black",
#       "mate_in": null,
#       "evaluation": 8,
#       "category": "Excellent",
#       "fen": "r3k2r/p1p1n1pp/3bbp2/2Pp4/P7/2N5/1PP1BPPP/R1B1K2R b KQkq - 0 13"
#     },
#     {
#       "move_number": 13,
#       "move": "d6c5",
#       "mover": "black",
#       "to_move": "white",
#       "mate_in": null,
#       "evaluation": 16,
#       "category": "Best",
#       "fen": "r3k2r/p1p1n1pp/4bp2/2bp4/P7/2N5/1PP1BPPP/R1B1K2R w KQkq - 0 14"
#     },
#     {
#       "move_number": 14,
#       "move": "c3b5",
#       "mover": "white",
#       "to_move": "black",
#       "mate_in": null,
#       "evaluation": -5,
#       "category": "Good",
#       "fen": "r3k2r/p1p1n1pp/4bp2/1Nbp4/P7/8/1PP1BPPP/R1B1K2R b KQkq - 1 14"
#     },
#     {
#       "move_number": 14,
#       "move": "a8c8",
#       "mover": "black",
#       "to_move": "white",
#       "mate_in": null,
#       "evaluation": 50,
#       "category": "Inaccuracy",
#       "fen": "2r1k2r/p1p1n1pp/4bp2/1Nbp4/P7/8/1PP1BPPP/R1B1K2R w KQk - 2 15"
#     },
#     {
#       "move_number": 15,
#       "move": "f2f3",
#       "mover": "white",
#       "to_move": "black",
#       "mate_in": null,
#       "evaluation": -99,
#       "category": "Mistake",
#       "fen": "2r1k2r/p1p1n1pp/4bp2/1Nbp4/P7/5P2/1PP1B1PP/R1B1K2R b KQk - 0 15"
#     },
#     {
#       "move_number": 15,
#       "move": "c7c6",
#       "mover": "black",
#       "to_move": "white",
#       "mate_in": null,
#       "evaluation": -102,
#       "category": "Best",
#       "fen": "2r1k2r/p3n1pp/2p1bp2/1Nbp4/P7/5P2/1PP1B1PP/R1B1K2R w KQk - 0 16"
#     },
#     {
#       "move_number": 16,
#       "move": "b5a7",
#       "mover": "white",
#       "to_move": "black",
#       "mate_in": null,
#       "evaluation": -360,
#       "category": "Blunder",
#       "fen": "2r1k2r/N3n1pp/2p1bp2/2bp4/P7/5P2/1PP1B1PP/R1B1K2R b KQk - 0 16"
#     },
#     {
#       "move_number": 16,
#       "move": "c8c7",
#       "mover": "black",
#       "to_move": "white",
#       "mate_in": null,
#       "evaluation": -273,
#       "category": "Inaccuracy",
#       "fen": "4k2r/N1r1n1pp/2p1bp2/2bp4/P7/5P2/1PP1B1PP/R1B1K2R w KQk - 1 17"
#     },
#     {
#       "move_number": 17,
#       "move": "a7c6",
#       "mover": "white",
#       "to_move": "black",
#       "mate_in": null,
#       "evaluation": -256,
#       "category": "Best",
#       "fen": "4k2r/2r1n1pp/2N1bp2/2bp4/P7/5P2/1PP1B1PP/R1B1K2R b KQk - 0 17"
#     },
#     {
#       "move_number": 17,
#       "move": "c7c6",
#       "mover": "black",
#       "to_move": "white",
#       "mate_in": null,
#       "evaluation": -170,
#       "category": "Inaccuracy",
#       "fen": "4k2r/4n1pp/2r1bp2/2bp4/P7/5P2/1PP1B1PP/R1B1K2R w KQk - 0 18"
#     },
#     {
#       "move_number": 18,
#       "move": "e2b5",
#       "mover": "white",
#       "to_move": "black",
#       "mate_in": null,
#       "evaluation": -163,
#       "category": "Best",
#       "fen": "4k2r/4n1pp/2r1bp2/1Bbp4/P7/5P2/1PP3PP/R1B1K2R b KQk - 1 18"
#     },
#     {
#       "move_number": 18,
#       "move": "e6d7",
#       "mover": "black",
#       "to_move": "white",
#       "mate_in": null,
#       "evaluation": -92,
#       "category": "Inaccuracy",
#       "fen": "4k2r/3bn1pp/2r2p2/1Bbp4/P7/5P2/1PP3PP/R1B1K2R w KQk - 2 19"
#     },
#     {
#       "move_number": 19,
#       "move": "b5c6",
#       "mover": "white",
#       "to_move": "black",
#       "mate_in": null,
#       "evaluation": -76,
#       "category": "Best",
#       "fen": "4k2r/3bn1pp/2B2p2/2bp4/P7/5P2/1PP3PP/R1B1K2R b KQk - 0 19"
#     },
#     {
#       "move_number": 19,
#       "move": "d7c6",
#       "mover": "black",
#       "to_move": "white",
#       "mate_in": null,
#       "evaluation": -10,
#       "category": "Inaccuracy",
#       "fen": "4k2r/4n1pp/2b2p2/2bp4/P7/5P2/1PP3PP/R1B1K2R w KQk - 0 20"
#     },
#     {
#       "move_number": 20,
#       "move": "a4a5",
#       "mover": "white",
#       "to_move": "black",
#       "mate_in": null,
#       "evaluation": -126,
#       "category": "Mistake",
#       "fen": "4k2r/4n1pp/2b2p2/P1bp4/8/5P2/1PP3PP/R1B1K2R b KQk - 0 20"
#     },
#     {
#       "move_number": 20,
#       "move": "c5b4",
#       "mover": "black",
#       "to_move": "white",
#       "mate_in": null,
#       "evaluation": -12,
#       "category": "Mistake",
#       "fen": "4k2r/4n1pp/2b2p2/P2p4/1b6/5P2/1PP3PP/R1B1K2R w KQk - 1 21"
#     },
#     {
#       "move_number": 21,
#       "move": "c2c3",
#       "mover": "white",
#       "to_move": "black",
#       "mate_in": null,
#       "evaluation": 0,
#       "category": "Best",
#       "fen": "4k2r/4n1pp/2b2p2/P2p4/1b6/2P2P2/1P4PP/R1B1K2R b KQk - 0 21"
#     },
#     {
#       "move_number": 21,
#       "move": "b4a5",
#       "mover": "black",
#       "to_move": "white",
#       "mate_in": null,
#       "evaluation": 443,
#       "category": "Blunder",
#       "fen": "4k2r/4n1pp/2b2p2/b2p4/8/2P2P2/1P4PP/R1B1K2R w KQk - 0 22"
#     },
#     {
#       "move_number": 22,
#       "move": "a1a5",
#       "mover": "white",
#       "to_move": "black",
#       "mate_in": null,
#       "evaluation": 446,
#       "category": "Best",
#       "fen": "4k2r/4n1pp/2b2p2/R2p4/8/2P2P2/1P4PP/2B1K2R b Kk - 0 22"
#     },
#     {
#       "move_number": 22,
#       "move": "e8g8",
#       "mover": "black",
#       "to_move": "white",
#       "mate_in": null,
#       "evaluation": 452,
#       "category": "Excellent",
#       "fen": "5rk1/4n1pp/2b2p2/R2p4/8/2P2P2/1P4PP/2B1K2R w K - 1 23"
#     },
#     {
#       "move_number": 23,
#       "move": "a5a7",
#       "mover": "white",
#       "to_move": "black",
#       "mate_in": null,
#       "evaluation": 411,
#       "category": "Good",
#       "fen": "5rk1/R3n1pp/2b2p2/3p4/8/2P2P2/1P4PP/2B1K2R b K - 2 23"
#     },
#     {
#       "move_number": 23,
#       "move": "f8e8",
#       "mover": "black",
#       "to_move": "white",
#       "mate_in": null,
#       "evaluation": 429,
#       "category": "Excellent",
#       "fen": "4r1k1/R3n1pp/2b2p2/3p4/8/2P2P2/1P4PP/2B1K2R w K - 3 24"
#     },
#     {
#       "move_number": 24,
#       "move": "c1f4",
#       "mover": "white",
#       "to_move": "black",
#       "mate_in": null,
#       "evaluation": -325,
#       "category": "Blunder",
#       "fen": "4r1k1/R3n1pp/2b2p2/3p4/5B2/2P2P2/1P4PP/4K2R b K - 4 24"
#     },
#     {
#       "move_number": 24,
#       "move": "e7g6",
#       "mover": "black",
#       "to_move": "white",
#       "mate_in": null,
#       "evaluation": 30,
#       "category": "Miss",
#       "fen": "4r1k1/R5pp/2b2pn1/3p4/5B2/2P2P2/1P4PP/4K2R w K - 5 25"
#     },
#     {
#       "move_number": 25,
#       "move": "e1f2",
#       "mover": "white",
#       "to_move": "black",
#       "mate_in": null,
#       "evaluation": -4,
#       "category": "Good",
#       "fen": "4r1k1/R5pp/2b2pn1/3p4/5B2/2P2P2/1P3KPP/7R b - - 6 25"
#     },
#     {
#       "move_number": 25,
#       "move": "g6f4",
#       "mover": "black",
#       "to_move": "white",
#       "mate_in": null,
#       "evaluation": -3,
#       "category": "Best",
#       "fen": "4r1k1/R5pp/2b2p2/3p4/5n2/2P2P2/1P3KPP/7R w - - 0 26"
#     },
#     {
#       "move_number": 26,
#       "move": "f2g3",
#       "mover": "white",
#       "to_move": "black",
#       "mate_in": null,
#       "evaluation": 0,
#       "category": "Best",
#       "fen": "4r1k1/R5pp/2b2p2/3p4/5n2/2P2PK1/1P4PP/7R b - - 1 26"
#     },
#     {
#       "move_number": 26,
#       "move": "f4e6",
#       "mover": "black",
#       "to_move": "white",
#       "mate_in": null,
#       "evaluation": 16,
#       "category": "Excellent",
#       "fen": "4r1k1/R5pp/2b1np2/3p4/8/2P2PK1/1P4PP/7R w - - 2 27"
#     },
#     {
#       "move_number": 27,
#       "move": "h1e1",
#       "mover": "white",
#       "to_move": "black",
#       "mate_in": null,
#       "evaluation": 18,
#       "category": "Best",
#       "fen": "4r1k1/R5pp/2b1np2/3p4/8/2P2PK1/1P4PP/4R3 b - - 3 27"
#     },
#     {
#       "move_number": 27,
#       "move": "e6c5",
#       "mover": "black",
#       "to_move": "white",
#       "mate_in": null,
#       "evaluation": 52,
#       "category": "Good",
#       "fen": "4r1k1/R5pp/2b2p2/2np4/8/2P2PK1/1P4PP/4R3 w - - 4 28"
#     },
#     {
#       "move_number": 28,
#       "move": "e1e8",
#       "mover": "white",
#       "to_move": "black",
#       "mate_in": null,
#       "evaluation": 53,
#       "category": "Excellent",
#       "fen": "4R1k1/R5pp/2b2p2/2np4/8/2P2PK1/1P4PP/8 b - - 0 28"
#     },
#     {
#       "move_number": 28,
#       "move": "c6e8",
#       "mover": "black",
#       "to_move": "white",
#       "mate_in": null,
#       "evaluation": 43,
#       "category": "Forced",
#       "fen": "4b1k1/R5pp/5p2/2np4/8/2P2PK1/1P4PP/8 w - - 0 29"
#     },
#     {
#       "move_number": 29,
#       "move": "a7a8",
#       "mover": "white",
#       "to_move": "black",
#       "mate_in": null,
#       "evaluation": 16,
#       "category": "Good",
#       "fen": "R3b1k1/6pp/5p2/2np4/8/2P2PK1/1P4PP/8 b - - 1 29"
#     },
#     {
#       "move_number": 29,
#       "move": "g8f8",
#       "mover": "black",
#       "to_move": "white",
#       "mate_in": null,
#       "evaluation": 15,
#       "category": "Best",
#       "fen": "R3bk2/6pp/5p2/2np4/8/2P2PK1/1P4PP/8 w - - 2 30"
#     },
#     {
#       "move_number": 30,
#       "move": "b2b4",
#       "mover": "white",
#       "to_move": "black",
#       "mate_in": null,
#       "evaluation": 20,
#       "category": "Best",
#       "fen": "R3bk2/6pp/5p2/2np4/1P6/2P2PK1/6PP/8 b - - 0 30"
#     },
#     {
#       "move_number": 30,
#       "move": "c5b3",
#       "mover": "black",
#       "to_move": "white",
#       "mate_in": null,
#       "evaluation": 335,
#       "category": "Blunder",
#       "fen": "R3bk2/6pp/5p2/3p4/1P6/1nP2PK1/6PP/8 w - - 1 31"
#     },
#     {
#       "move_number": 31,
#       "move": "b4b5",
#       "mover": "white",
#       "to_move": "black",
#       "mate_in": null,
#       "evaluation": 397,
#       "category": "Best",
#       "fen": "R3bk2/6pp/5p2/1P1p4/8/1nP2PK1/6PP/8 b - - 0 31"
#     },
#     {
#       "move_number": 31,
#       "move": "b3d2",
#       "mover": "black",
#       "to_move": "white",
#       "mate_in": null,
#       "evaluation": 658,
#       "category": "Mistake",
#       "fen": "R3bk2/6pp/5p2/1P1p4/8/2P2PK1/3n2PP/8 w - - 1 32"
#     },
#     {
#       "move_number": 32,
#       "move": "b5b6",
#       "mover": "white",
#       "to_move": "black",
#       "mate_in": null,
#       "evaluation": 666,
#       "category": "Best",
#       "fen": "R3bk2/6pp/1P3p2/3p4/8/2P2PK1/3n2PP/8 b - - 0 32"
#     },
#     {
#       "move_number": 32,
#       "move": "d5d4",
#       "mover": "black",
#       "to_move": "white",
#       "mate_in": null,
#       "evaluation": 788,
#       "category": "Good",
#       "fen": "R3bk2/6pp/1P3p2/8/3p4/2P2PK1/3n2PP/8 w - - 0 33"
#     },
#     {
#       "move_number": 33,
#       "move": "b6b7",
#       "mover": "white",
#       "to_move": "black",
#       "mate_in": null,
#       "evaluation": 893,
#       "category": "Best",
#       "fen": "R3bk2/1P4pp/5p2/8/3p4/2P2PK1/3n2PP/8 b - - 0 33"
#     },
#     {
#       "move_number": 33,
#       "move": "d4c3",
#       "mover": "black",
#       "to_move": "white",
#       "mate_in": 10,
#       "evaluation": 9990,
#       "category": "Good",
#       "fen": "R3bk2/1P4pp/5p2/8/8/2p2PK1/3n2PP/8 w - - 0 34"
#     },
#     {
#       "move_number": 34,
#       "move": "b7b8q",
#       "mover": "white",
#       "to_move": "black",
#       "mate_in": 9,
#       "evaluation": 9991,
#       "category": "Best",
#       "fen": "RQ2bk2/6pp/5p2/8/8/2p2PK1/3n2PP/8 b - - 0 34"
#     },
#     {
#       "move_number": 34,
#       "move": "f8f7",
#       "mover": "black",
#       "to_move": "white",
#       "mate_in": 1,
#       "evaluation": 9999,
#       "category": "Excellent",
#       "fen": "RQ2b3/5kpp/5p2/8/8/2p2PK1/3n2PP/8 w - - 1 35"
#     },
#     {
#       "move_number": 35,
#       "move": "b8e8",
#       "mover": "white",
#       "to_move": "black",
#       "mate_in": 0,
#       "evaluation": 10000,
#       "category": "Best",
#       "fen": "R3Q3/5kpp/5p2/8/8/2p2PK1/3n2PP/8 b - - 0 35"
#     }
#   ],
#   "eval_history": [
#     37,
#     47,
#     35,
#     33,
#     25,
#     33,
#     -50,
#     -43,
#     -40,
#     -43,
#     -437,
#     -424,
#     -412,
#     -27,
#     -28,
#     158,
#     -49,
#     82,
#     7,
#     10,
#     -34,
#     -18,
#     -92,
#     24,
#     8,
#     16,
#     -5,
#     50,
#     -99,
#     -102,
#     -360,
#     -273,
#     -256,
#     -170,
#     -163,
#     -92,
#     -76,
#     -10,
#     -126,
#     -12,
#     0,
#     443,
#     446,
#     452,
#     411,
#     429,
#     -325,
#     30,
#     -4,
#     -3,
#     0,
#     16,
#     18,
#     52,
#     53,
#     43,
#     16,
#     15,
#     20,
#     335,
#     397,
#     658,
#     666,
#     788,
#     893,
#     9990,
#     9991,
#     9999,
#     10000
#   ]
# }

# %%
fen = "4Q3/K7/8/3B4/5Q1p/7P/5P1k/8 b - - 2 56"
board = chess.Board(fen)
print(board.legal_moves.count())
# Out:
# 2

# %%
fen = "rnbqkbnr/pp1ppppp/8/2p5/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2"
board = chess.Board(fen)

openings_url = "baron30.bin"
openings = chess.polyglot.open_reader(openings_url)

# for hehe in openings.find_all(board):
#     print(hehe.move)

print(board.epd())
# Out:
# rnbqkbnr/pp1ppppp/8/2p5/4P3/8/PPPP1PPP/RNBQKBNR w KQkq -

# %%
print(len(openings))  # сколько всего записей загрузилось
print(list(openings.items())[:3])  # первые три пары ключ-значение, глазами оценить структуру
# Out:
# 3733
# [('rnbqkbnr/pppppppp/8/8/8/7N/PPPPPPPP/RNBQKB1R b KQkq -', ('A00', 'Amar Opening')), ('rnbqkbnr/ppp2ppp/8/3pp3/5P2/6PN/PPPPP2P/RNBQKB1R b KQkq -', ('A00', 'Amar Opening: Paris Gambit')), ('rn1qkbnr/ppp2ppp/8/3p4/8/6PB/PPPPP3/RNBQ1RK1 b kq -', ('A00', 'Amar Opening: Paris Gambit, Gent Gambit'))]

# %%
calculate_winrate(70) - calculate_winrate(-40)
# Out:
# 10.083641310897491
